# %% [markdown]
# <a href="https://colab.research.google.com/github/bargida/AI_codes/blob/main/Untitled31.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('earthquakes.csv', index_col=0, parse_dates=[0], usecols=[0, 1])
#parse_dates bu df ichidan (2010-01-20) aynan bittasini ajratib olish u/n ishlatamiz Masalan:

# df['year] = [i.year for i in df.index] (yilini ajratib u/n)
#df.head

df.reset_index(inplace=True) #duplicate bob qogani uchun reindexladim
df = df[~df.index.duplicated(keep='first')]
df.drop(['year', 'day', 'month', 'richter', 'area'], axis=1, inplace=True, errors='ignore')
df.columns = ['region', 'deaths']
df
# Out:
#                      region   deaths
# 0                 Guatemala   2000.0
# 1                    Russia   4700.0
# 2                    Turkey   3500.0
# 3                    Turkey   1000.0
# 4                     India  19000.0
# ..                      ...      ...
# 118  Afghanistan-Tajikistan   4000.0
# 119              New Guinea   2183.0
# 120                Colombia   1185.0
# 121                  Turkey  17118.0
# 122                  Taiwan   2400.0
#
# [123 rows x 2 columns]

# %%
df.shape
# Out:
# (123, 2)

# %%
plt.figure(figsize=(30,8))
sns.barplot(x=df.index, y=df['deaths'])
plt.xticks(rotation=90) #tik larni orasini ochib beradi
plt.show()

# %%
df.head()
# Out:
#    year     month  day  richter                         area     region  \
# 0  1902     April   19      7.5  Quezaltenango and San Marco  Guatemala
# 1  1902  December   16      6.4                   Uzbekistan     Russia
# 2  1903     April   28      7.0                    Malazgirt     Turkey
# 3  1903       May   28      5.8                         Gole     Turkey
# 4  1905     April    4      7.5                       Kangra      India
#
#     deaths
# 0   2000.0
# 1   4700.0
# 2   3500.0
# 3   1000.0
# 4  19000.0

# %%
import datetime as dt

# %%
now = dt.datetime.now()

# %%
type(now)
# Out:
# datetime.datetime

# %%
now.month
# Out:
# 6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123 entries, 0 to 122
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   year     123 non-null    int64
#  1   month    123 non-null    object
#  2   day      123 non-null    int64
#  3   richter  123 non-null    float64
#  4   area     119 non-null    object
#  5   region   122 non-null    object
#  6   deaths   121 non-null    float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 6.9+ KB
